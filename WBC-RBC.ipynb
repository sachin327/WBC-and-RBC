# %%
to_run=True

# %%
if to_run:
  # !git clone https://github.com/sachin327/WBC-and-RBC
  # %cd WBC-and-RBC
  to_run = False
# Out:
# Cloning into 'WBC-and-RBC'...
# remote: Enumerating objects: 406, done.
# remote: Counting objects: 100% (406/406), done.
# remote: Compressing objects: 100% (398/398), done.
# remote: Total 767 (delta 12), reused 381 (delta 3), pack-reused 361
# Receiving objects: 100% (767/767), 10.96 MiB | 23.43 MiB/s, done.
# Resolving deltas: 100% (115/115), done.
# /content/WBC-and-RBC

# %%
# %cd '/content/WBC-and-RBC/1_Image_Annotation'
# Out:
# /content/WBC-and-RBC/1_Image_Annotation

# %%
# !python  Convert_to_YOLO_format.py

# %%
# %cd '/content/WBC-and-RBC/2_Training'
# Out:
# /content/WBC-and-RBC/2_Training

# %%
# !python Download_and_Convert_YOLO_weights.py
# Out:
# ...
#
# | |                           #                     | 7568 Elapsed Time: 0:00:02
# Downloaded Raw yolov3.weights in 4.1 seconds
#
# 2020-10-01 12:33:28.926300: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcudart.so.10.1
# Loading weights.
# Weights Header:  0 2 0 [32013312]
# Parsing Darknet config.
# Creating Keras model.
# Parsing section net_0
# Parsing section convolutional_0
# conv2d bn leaky (3, 3, 3, 32)
# 2020-10-01 12:33:30.360874: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcuda.so.1
# 2020-10-01 12:33:30.401121: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:982] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-10-01 12:33:30.401685: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1716] Found device 0 with properties:
# ...

# %%
# !python Train_YOLO.py
# Out:
# 2020-10-01 12:33:41.092785: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcudart.so.10.1
# 2020-10-01 12:33:42.486467: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcuda.so.1
# 2020-10-01 12:33:42.519833: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:982] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-10-01 12:33:42.520434: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1716] Found device 0 with properties:
# pciBusID: 0000:00:04.0 name: Tesla T4 computeCapability: 7.5
# coreClock: 1.59GHz coreCount: 40 deviceMemorySize: 14.73GiB deviceMemoryBandwidth: 298.08GiB/s
# 2020-10-01 12:33:42.520489: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcudart.so.10.1
# ...

# %%
# %cd '/content/WBC-and-RBC/3_Inference'
# Out:
# /content/WBC-and-RBC/3_Inference

# %%
# !python Detector.py
# Out:
# 2020-10-01 13:28:19.891205: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcudart.so.10.1
# 2020-10-01 13:28:21.350334: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcuda.so.1
# 2020-10-01 13:28:21.389981: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:982] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-10-01 13:28:21.390657: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1716] Found device 0 with properties:
# pciBusID: 0000:00:04.0 name: Tesla T4 computeCapability: 7.5
# coreClock: 1.59GHz coreCount: 40 deviceMemorySize: 14.73GiB deviceMemoryBandwidth: 298.08GiB/s
# 2020-10-01 13:28:21.390697: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcudart.so.10.1
# ...
